# %% [markdown]
# Model Comparision

# %%
# ================================
# Model Comparison Summary
# ================================

import pandas as pd

# Example metrics from your earlier runs
# Replace numbers with your actual outputs if you want exact values
results = {
    "Model": [
        "Classical SVC",
        "Artificial Neural Network (ANN)",
        "Quantum SVC (QSVC)",
        "Quantum Neural Network (QNN)",
        "Variational Quantum Classifier (VQC)",
        "Bagging-QSVC Ensemble"
    ],
    "Accuracy (%)": [47.5, 57.3, 67.2, 60.53, 75.41, 90.1],
    "Type": [
        "Classical", "Classical",
        "Quantum", "Quantum", "Quantum", "Quantum Ensemble"
    ]
}

df_results = pd.DataFrame(results)

print("=== Model Performance Comparison ===")
display(df_results.style.background_gradient(cmap="coolwarm"))

# ================================
# Step 15(B): Visual Comparison
# ================================

import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
plt.bar(df_results["Model"], df_results["Accuracy (%)"])
plt.xticks(rotation=45, ha="right")
plt.ylabel("Accuracy (%)")
plt.title("Model Accuracy Comparison: Classical vs Quantum")
plt.grid(axis="y")
plt.show()
# Out:
# === Model Performance Comparison ===
# <style type="text/css">
# #T_3a24d_row0_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_3a24d_row1_col1 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_3a24d_row2_col1 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_3a24d_row3_col1 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_3a24d_row4_col1 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_3a24d_row5_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_3a24d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3a24d_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_3a24d_level0_col1" class="col_heading level0 col1" >Accuracy (%)</th>
#       <th id="T_3a24d_level0_col2" class="col_heading level0 col2" >Type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
import json

model_results = {
    "SVM": acc_svm,
    "ANN": acc_ann,
    "QSVC": acc_qsvc,
    "QNN": acc_qnn,
    "VQC": acc_vqc,
    "Bagging-QSVC": acc_bag_qsvc
}

with open("model_accuracies.json", "w") as f:
    json.dump(model_results, f)

print("✅ Model accuracies saved successfully")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 import json
#       3 model_results = {
# ----> 4     "SVM": acc_svm,
#       5     "ANN": acc_ann,
#       6     "QSVC": acc_qsvc,
#       7     "QNN": acc_qnn,
#       8     "VQC": acc_vqc,
#       9     "Bagging-QSVC": acc_bag_qsvc
#      10 }
#      12 with open("model_accuracies.json", "w") as f:
#      13     json.dump(model_results, f)
#
# NameError: name 'acc_svm' is not defined

# %%
from sklearn.metrics import accuracy_score

acc_svm = accuracy_score(y_test, y_pred_svm)
acc_ann = accuracy_score(y_test, y_pred_ann)
acc_qsvc = accuracy_score(y_test, y_pred_qsvc)
acc_qnn = accuracy_score(y_test, y_pred_qnn)
acc_vqc = accuracy_score(y_test, y_pred_vqc)
acc_bag_qsvc = accuracy_score(y_test, y_pred_bag_qsvc)

print("Accuracies computed successfully")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 from sklearn.metrics import accuracy_score
# ----> 3 acc_svm = accuracy_score(y_test, y_pred_svm)
#       4 acc_ann = accuracy_score(y_test, y_pred_ann)
#       5 acc_qsvc = accuracy_score(y_test, y_pred_qsvc)
#
# NameError: name 'y_test' is not defined

# %%
import pandas as pd
import matplotlib.pyplot as plt

# ================================
# MODEL COMPARISON (ORIGINAL VALUES)
# ================================

model_comparison = pd.DataFrame({
    "Model": [
        "SVM",
        "ANN",
        "QSVC",
        "QNN",
        "VQC",
        "Bagging-QSVC"
    ],
    "Accuracy (%)": [
        acc_svm * 100,
        acc_ann * 100,
        acc_qsvc * 100,
        acc_qnn * 100,
        acc_vqc * 100,
        acc_bag_qsvc * 100
    ]
})

print("📊 MODEL PERFORMANCE COMPARISON")
display(model_comparison)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 18
#       2 import matplotlib.pyplot as plt
#       4 # ================================
#       5 # MODEL COMPARISON (ORIGINAL VALUES)
#       6 # ================================
#       8 model_comparison = pd.DataFrame({
#       9     "Model": [
#      10         "SVM",
#      11         "ANN",
#      12         "QSVC",
#      13         "QNN",
#      14         "VQC",
#      15         "Bagging-QSVC"
#      16     ],
#      17     "Accuracy (%)": [
# ---> 18         acc_svm * 100,
#      19         acc_ann * 100,
#      20         acc_qsvc * 100,
#      21         acc_qnn * 100,
#      22         acc_vqc * 100,
#      23         acc_bag_qsvc * 100
#      24     ]
#      25 })
#      27 print("📊 MODEL PERFORMANCE COMPARISON")
#      28 display(model_comparison)
#
# NameError: name 'acc_svm' is not defined
