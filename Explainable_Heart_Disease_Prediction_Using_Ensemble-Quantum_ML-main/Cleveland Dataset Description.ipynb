# %%
import numpy as np
import pandas as pd
import seaborn as sns
from scipy import stats
import matplotlib.pylab as plt

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Features Dictionary

# %%
data = pd.read_csv('Cleveland Dataset.csv')
print()

# %% [raw]
# # Features Dictionary:# Features Dictionary:
# 1. Age:	     Age in years
# 2. Sex:	     1= male, and 0= female
# 3. CP:	     Chest Pain types: 1= typical angina, 2= atypical angina, 3= non-angina pain, and 4= asymptomatic
# 4. trestbps: Resting blood pressure (in mm Hg)
# 5. chol:	 Serum cholesterol in mg/dl
# 6. fbs:	     Fasting blood sugar > 120 mg/dl, whether 1 = true, or 0 = false
# 7. restecg:  Resting electrocardiographic result: 0= normal, 1= having ST-T wave abnormality, 2=showing probable
#              or definite left ventricular hypertrophy
# 8. thalach:  maximum heart rate reached
# 9. exang:	 Exercise induced angina (0= no, and 1= yes)
# 10. oldpeak: ST depression caused by exercise relative to rest
# 11. slope:	 The peak exercise ST segment slope: 1= ascending, 2= flat, 3= descending
# 12. ca:	     Number of main vessels (0–3)
# 13. thal:	 Exercise Thallium heart scan: 1= normal, 2= fixed defect, and 3= reversible defect
# 14. target:	 Heart disease diagnosing: (1= yes, 0= no)

# %% [markdown]
# ### Cleveland Dataset(samples,features)

# %%
 data.shape
# Out:
# (303, 14)

# %% [markdown]
# ### Head of Cleveland Dataset

# %%
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %% [markdown]
# ### Cleveland Dataset Description

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
# features cardinality 
data.nunique()
# Out:
# age          41
# sex           2
# cp            4
# trestbps     49
# chol        152
# fbs           2
# restecg       3
# thalach      91
# exang         2
# oldpeak      40
# slope         3
# ca            5
# thal          4
# target        2
# dtype: int64

# %%
# rename the features 
data = data.rename(columns = {'cp':'Chest pain type', 'trestbps':'Resting blood pressure', 'chol': 'Cholesterol','fbs': 'Fasting blood sugar', 
                              'restecg' : 'Rest electrocardiographic', 'thalach': 'Maximum heart rate', 'exang': 'Exercise induced angina','target':'Heart disease',
                              'oldpeak': 'ST depression', 'slope': 'ST slope', 'ca':'Number of major vessels', 'thal': 'Thallium heart scan'}, errors="raise")

# %%
# rename the lables
data['sex'][data['sex'] == 0] = 'female'
data['sex'][data['sex'] == 1] = 'male'

data['Chest pain type'][data['Chest pain type'] == 0] = 'typical'
data['Chest pain type'][data['Chest pain type'] == 1] = 'atypical'
data['Chest pain type'][data['Chest pain type'] == 2] = 'non-anginal'
data['Chest pain type'][data['Chest pain type'] == 3] = 'asymptomatic'

data['Fasting blood sugar'][data['Fasting blood sugar'] == 0] = 'lower than 120mg/ml'
data['Fasting blood sugar'][data['Fasting blood sugar'] == 1] = 'greater than 120mg/ml'

data['Rest electrocardiographic'][data['Rest electrocardiographic'] == 0] = 'normal'
data['Rest electrocardiographic'][data['Rest electrocardiographic'] == 1] = 'ST-T wave abnormality'
data['Rest electrocardiographic'][data['Rest electrocardiographic'] == 2] = 'left ventricular hypertrophy'

data['Exercise induced angina'][data['Exercise induced angina'] == 0] = 'no'
data['Exercise induced angina'][data['Exercise induced angina'] == 1] = 'yes'

data['ST slope'][data['ST slope'] == 0] = 'upsloping'
data['ST slope'][data['ST slope'] == 1] = 'flat'
data['ST slope'][data['ST slope'] == 2] = 'downsloping'

data['Thallium heart scan'][data['Thallium heart scan'] == 0] = 'unknown'
data['Thallium heart scan'][data['Thallium heart scan'] == 1] = 'fixed defect'
data['Thallium heart scan'][data['Thallium heart scan'] == 2] = 'normal'
data['Thallium heart scan'][data['Thallium heart scan'] == 3] = 'reversable defect'

data['Heart disease'][data['Heart disease'] == 0] = 'NO'
data['Heart disease'][data['Heart disease'] == 1] = 'Yes'

# %%
# Grouping Features by data type 
# numerical fearures 
numerical_features = ['age', 'Cholesterol', 'Resting blood pressure', 'Maximum heart rate','ST depression']

# categorical features
categorical_features = ['sex', 'Fasting blood sugar', 'Exercise induced angina','Number of major vessels','Chest pain type', 'Rest electrocardiographic', 'ST slope', 'Thallium heart scan', 'Heart disease']

# %% [markdown]
# ### Continuous Features Quality Report

# %%
# continuous features quality report
pd.set_option("display.float", "{:.2f}".format)
data[numerical_features].describe().T
# Out:
#                         count   mean   std    min    25%    50%    75%    max
# age                    303.00  54.37  9.08  29.00  47.50  55.00  61.00  77.00
# Cholesterol            303.00 246.26 51.83 126.00 211.00 240.00 274.50 564.00
# Resting blood pressure 303.00 131.62 17.54  94.00 120.00 130.00 140.00 200.00
# Maximum heart rate     303.00 149.65 22.91  71.00 133.50 153.00 166.00 202.00
# ST depression          303.00   1.04  1.16   0.00   0.00   0.80   1.60   6.20

# %% [markdown]
# ### Continuous Features Distribution

# %%
# visualizing continuous features distribution
L = len(numerical_features)
ncol = 2
nrow = int(np.ceil(L / ncol))
remove_last = (nrow * ncol) - L

fig, ax = plt.subplots(nrow, ncol, figsize=(17, 13))   
fig.subplots_adjust(top=0.90, hspace=0.45, wspace=0.25)

ax = ax.flatten()
if remove_last > 0:
    ax[-remove_last].set_visible(False)

i = 0
for col in numerical_features:
    plt.sca(ax[i])
    ax[i].set_facecolor('#F6F5F4')

    sns.kdeplot(
        data=data,
        x=col,
        hue="Heart disease",
        palette='Spectral',
        linewidth=2
    )

    ax[i].set_xlabel(col, fontsize=12)
    ax[i].set_ylabel("Density", fontsize=12)
    ax[i].tick_params(axis='x', labelrotation=30, labelsize=10)
    ax[i].tick_params(axis='y', labelsize=10)

    sns.despine(ax=ax[i], right=True)
    i += 1

plt.suptitle(
    'Continuous Features Kernel Density Estimate (KDE) Plot',
    fontsize=22
)
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %% [markdown]
# ### Continuous Features Boxplot

# %%
# continuous features boxplot
L = len(numerical_features)
ncol = 2
nrow = int(np.ceil(L / ncol))
remove_last = (nrow * ncol) - L

fig, ax = plt.subplots(nrow, ncol, figsize=(18, 14))
fig.subplots_adjust(top=0.90, hspace=0.45, wspace=0.25)

ax = ax.flatten()
if remove_last > 0:
    ax[-remove_last].set_visible(False)

i = 0
for col in numerical_features:
    plt.sca(ax[i])
    ax[i].set_facecolor('#F6F5F4')

    sns.boxplot(
        data=data,
        x='Heart disease',
        y=col,
        palette='Spectral',
        width=0.6
    )

    ax[i].set_xlabel('Heart disease', fontsize=12)
    ax[i].set_ylabel(col, fontsize=12)
    ax[i].tick_params(axis='both', labelsize=10)

    sns.despine(ax=ax[i], right=True)
    i += 1

plt.suptitle(
    'Continuous Features Boxplot',
    fontsize=22
)
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %% [markdown]
# ### Pearson correlation

# %%
# Pearson correlation (corrected mask)
num_df = data[numerical_features]
corr = num_df.corr(method='pearson')

mask = np.triu(np.ones_like(corr, dtype=bool), k=1)

fig, ax = plt.subplots(figsize=(10, 7))
cmap = sns.color_palette('Spectral', as_cmap=True)

sns.heatmap(
    corr,
    mask=mask,
    cmap=cmap,
    vmin=-1,
    vmax=1,
    center=0,
    annot=True,
    fmt=".2f",
    annot_kws={"size": 11},
    square=True,
    linewidths=0.6,
    cbar_kws={"shrink": 0.8}
)

ax.set_title(
    "Continuous Features (Pearson Correlation)",
    fontsize=18,
    pad=15
)
ax.tick_params(axis='both', labelsize=11)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Point_biserial correlation

# %%
# point_biserial correlation
num_target= ['age', 'Cholesterol', 'Resting blood pressure', 'Maximum heart rate','ST depression', 'Heart disease']
data['Heart disease'][data['Heart disease'] == 'NO'] = 0
data['Heart disease'][data['Heart disease'] == 'Yes'] = 1

def point_biserial(x, y):
    pb = stats.pointbiserialr(x, y)
    return pb[0]

rows= []
for x in num_target:
    col = []
    for y in num_target :
        pbs =point_biserial(data[x], data[y]) 
        col.append(round(pbs,2))  
    rows.append(col)  
    
pbs_results = np.array(rows)
DF = pd.DataFrame(pbs_results, columns = data[num_target].columns, index =data[num_target].columns)

mask = np.triu(np.ones_like(DF, dtype=bool), k=1.00)
corr = DF.mask(mask)

f, ax = plt.subplots(figsize=(8, 5), facecolor=None)
cmap = sns.color_palette(palette='Spectral', as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=1.0, vmin=-1, center=0, annot=True,
            square=False, linewidths=.5, cbar_kws={"shrink": 0.75})
ax.set_title("Continuous features against target feature \n (point-biserial correlation)", fontsize=20, y= 1.05);

# %% [markdown]
# ### Categorical features

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

def hist_plot(data, categorical_features):    
    L = len(categorical_features)
    ncol = 3
    nrow = int(np.ceil(L / ncol))
    
    fig, axes = plt.subplots(nrow, ncol, figsize=(20, nrow * 5.5), dpi=100) 
    axes = axes.flatten() 
    
    fig.suptitle('Categorical Feature Distribution by Heart Disease Status', 
                 fontsize=26, fontweight='bold', y=1.02, color='#2C3E50')

    # Verified professional tonal pairs
    tonal_pairs = [
        ['#A9C1D9', '#34568B'], ['#E6B0AA', '#943126'], ['#A2D9CE', '#1E8449'], 
        ['#D7BDE2', '#76448A'], ['#F9E79F', '#B7950B'], ['#AED6F1', '#21618C'], 
        ['#D5DBDB', '#2C3E50']
    ]

    for i, col in enumerate(categorical_features):
        ax = axes[i] 
        ax.set_facecolor('#FAF9F8') 
        
        # Cross-check: Get the unique values present in the data for the x-axis labels
        unique_categories = sorted(data[col].unique())
        
        current_pair = tonal_pairs[i % len(tonal_pairs)]
        
        # Explicitly set the order to ensure values appear on the x-axis
        g = sns.countplot(data=data, x=col, hue="Heart disease", order=unique_categories,
                          palette=current_pair, ax=ax, edgecolor='white', linewidth=1.2)
        
        # Add Count Labels on top
        for p in g.patches:
            height = p.get_height()
            if height > 0:
                g.annotate(f'{int(height)}', 
                           (p.get_x() + p.get_width() / 2., height), 
                           ha='center', va='center', 
                           xytext=(0, 10), textcoords='offset points',
                           fontsize=12, fontweight='bold', color='#34495E')

        # Formatting titles and axis labels
        ax.set_title(f'Distribution of {col.replace("_", " ").title()}', 
                     fontsize=18, fontweight='bold', pad=20)
        ax.set_xlabel(col.title(), fontsize=12, fontweight='bold') # Restored X-label for clarity
        ax.set_ylabel("Total Count", fontsize=14, fontweight='bold')
        
        # Ensure x-axis labels are visible and rotated if needed
        plt.setp(ax.get_xticklabels(), rotation=0, fontsize=11, fontweight='600')
        
        ax.legend(title='Heart Disease', labels=['No', 'Yes'], frameon=False)
        sns.despine(ax=ax, offset=10) 

    for j in range(i + 1, len(axes)):
        axes[j].axis('off')

    plt.tight_layout() 
    plt.show()

hist_plot(data, categorical_features)

# %% [markdown]
# ### Cramer's v correlation

# %%
# cramer's v correlation 
def cramers_v(x, y): 
    confusion_matrix = pd.crosstab(x,y)
    chi2 = stats.chi2_contingency(confusion_matrix)[0]
    n = confusion_matrix.sum().sum()
    phi2 = chi2/n
    r,k = confusion_matrix.shape
    phi2corr = max(0, phi2-((k-1)*(r-1))/(n-1))
    rcorr = r-((r-1)**2)/(n-1)
    kcorr = k-((k-1)**2)/(n-1)
    return np.sqrt(phi2corr/min((kcorr-1),(rcorr-1)))

# calculate the correlation coefficients using the above function
rows= []
cat_df= data [categorical_features]
for x in cat_df:
    col = []
    for y in cat_df :
        cramers =cramers_v(cat_df[x], cat_df[y]) 
        col.append(round(cramers,2))
    rows.append(col)
    
cramers_results = np.array(rows)
df = pd.DataFrame(cramers_results, columns = cat_df.columns, index = cat_df.columns)

# plot the heat map
mask = np.triu(np.ones_like(df, dtype=bool))
corr = df.mask(mask)
f, ax = plt.subplots(figsize=(10, 6), facecolor=None)
cmap = sns.color_palette(palette='Spectral', as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=1.0, vmin=0, center=0, annot=True,
            square=False, linewidths=.01, cbar_kws={"shrink": 0.75})
ax.set_title("Categorical Features (Cramer's V Correlation)", fontsize=20, y= 1.05);
